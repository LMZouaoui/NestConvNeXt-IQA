# %%
######### LWIR_IQA_dataset ----

# %run run.py --batch_size 40  --svpath  '/home/NestCovNeXt_IQA/Save_NestCovNeXt_IQA/'  --epochs 20 --lr 2e-5 --gpunum 0  --datapath  F:/LWIR_dataset/LWIR_IQA_dataset-main/    --dataset LWIR_IQA  --vesion 1   --seed 2022

# %%
######### LWIR_IQA_dataset ---- by_Distortion_Class

# %run run.py --batch_size 40  --svpath  '/home/NestCovNeXt_IQA/Save_NestCovNeXt_IQA/'  --epochs 20 --lr 2e-5 --gpunum 0  --datapath  F:/LWIR_dataset/LWIR_IQA_dataset-main/nu/    --dataset LWIR_IQA_by_class  --vesion 1    --seed 2022

# %%
######### TIIQAD_dataset ----

# %run run.py --batch_size 40  --svpath  '/home/CovNeXt/Save_NestCovNeXt_IQA/'  --epochs 20 --lr 2e-5 --gpunum 0  --datapath  F:/LWIR_dataset/TIIQAD/    --dataset TIIQAD  --vesion 1    --seed 2022
